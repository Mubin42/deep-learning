# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
link = 'https://drive.google.com/file/d/1BPigFUj66zgt4F_fcIER2AZ6JQo63FPM/view?usp=sharing'

# to get the id part of the file
id = link.split("/")[-2]
 
downloaded = drive.CreateFile({'id':id})
downloaded.GetContentFile('50_startups.csv') 
 
dataset = pd.read_csv('50_startups.csv')
print(dataset.shape)
dataset.head()
# Out:
# (10000, 14)
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
X =  dataset.iloc[:,3:13] #independent features
y = dataset.iloc[:,13] #dependent features
print(X)
print(y)
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# 0             1               1        101348.88
# 1             0               1        112542.58
# 2             1               0        113931.57
# 3             0               0         93826.63
# 4             1               1         79084.10
# ...         ...             ...              ...
# 9995          1               0         96270.64
# 9996          1               1        101699.77
# 9997          0               1         42085.58
# 9998          1               0         92888.52
# 9999          1               0         38190.78
#
# [10000 rows x 10 columns]
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
# create dummy variable
geography = pd.get_dummies(X["Geography"], drop_first=True)
gender = pd.get_dummies(X["Gender"], drop_first=True)
print(geography, gender)
# Out:
#       Germany  Spain
# 0           0      0
# 1           0      1
# 2           0      0
# 3           0      0
# 4           0      1
# ...       ...    ...
# 9995        0      0
# 9996        0      0
# 9997        0      0
# 9998        1      0
# 9999        0      0
#
# [10000 rows x 2 columns]       Male
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ...    ...
# 9995     1
# 9996     1
# 9997     0
# 9998     1
# 9999     0
#
# [10000 rows x 1 columns]

# %%
X = pd.concat([X, geography,gender], axis=1)
X
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Germany  Spain  Male
# 0             1               1        101348.88        0      0     0
# 1             0               1        112542.58        0      1     0
# 2             1               0        113931.57        0      0     0
# 3             0               0         93826.63        0      0     0
# 4             1               1         79084.10        0      1     0
# ...         ...             ...              ...      ...    ...   ...
# 9995          1               0         96270.64        0      0     1
# 9996          1               1        101699.77        0      0     1
# 9997          0               1         42085.58        0      0     0
# 9998          1               0         92888.52        1      0     1
# 9999          1               0         38190.78        0      0     0
#
# [10000 rows x 13 columns]

# %%
# Drop unnecessary columns
X = X.drop(['Geography', 'Gender'], axis=1)
X
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Germany  Spain  Male
# 0                  1        101348.88        0      0     0
# 1                  1        112542.58        0      1     0
# 2                  0        113931.57        0      0     0
# 3                  0         93826.63        0      0     0
# 4                  1         79084.10        0      1     0
# ...              ...              ...      ...    ...   ...
# 9995               0         96270.64        0      0     1
# 9996               1        101699.77        0      0     1
# 9997               1         42085.58        0      0     0
# 9998               0         92888.52        1      0     1
# 9999               0         38190.78        0      0     0
#
# [10000 rows x 11 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
# feature scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout

# %%
X_train.shape
# Out:
# (8000, 11)

# %%
# Initialising the ANN
classifier = Sequential()

# Adding the input layer and the first hidden layer
classifier.add(Dense(units = 10, kernel_initializer = 'he_normal',activation='relu',input_dim = 11))
classifier.add(Dropout(0.3))
# Adding the second hidden layer
classifier.add(Dense(units = 20, kernel_initializer = 'he_normal',activation='relu'))
classifier.add(Dropout(0.4))
# Adding the third hidden layer
classifier.add(Dense(units = 15, kernel_initializer = 'he_normal',activation='relu'))
classifier.add(Dropout(0.4))
# Adding the output layer
classifier.add(Dense(units = 1, kernel_initializer = 'glorot_uniform', activation = 'sigmoid'))

# Compiling the ANN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
classifier.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_14 (Dense)            (None, 10)                120
#
#  dropout (Dropout)           (None, 10)                0
#
#  dense_15 (Dense)            (None, 20)                220
#
#  dropout_1 (Dropout)         (None, 20)                0
#
#  dense_16 (Dense)            (None, 15)                315
#
#  dropout_2 (Dropout)         (None, 15)                0
#
#  dense_17 (Dense)            (None, 1)                 16
#
# =================================================================
# Total params: 671
# Trainable params: 671
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fitting the ANN to the Training set
model_history=classifier.fit(X_train, 
                             y_train,
                             validation_split=0.33, 
                             batch_size = 10, 
                             epochs = 100)
# Out:
# Epoch 1/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.7638 - accuracy: 0.6869 - val_loss: 0.5123 - val_accuracy: 0.7955
# Epoch 2/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.5525 - accuracy: 0.7757 - val_loss: 0.4891 - val_accuracy: 0.7955
# Epoch 3/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.5157 - accuracy: 0.7921 - val_loss: 0.4746 - val_accuracy: 0.7955
# Epoch 4/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4968 - accuracy: 0.7942 - val_loss: 0.4684 - val_accuracy: 0.7955
# Epoch 5/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4851 - accuracy: 0.7987 - val_loss: 0.4537 - val_accuracy: 0.7955
# Epoch 6/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4789 - accuracy: 0.7985 - val_loss: 0.4493 - val_accuracy: 0.7955
# Epoch 7/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4641 - accuracy: 0.8020 - val_loss: 0.4439 - val_accuracy: 0.7955
# Epoch 8/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4623 - accuracy: 0.8007 - val_loss: 0.4428 - val_accuracy: 0.7955
# Epoch 9/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4585 - accuracy: 0.8028 - val_loss: 0.4374 - val_accuracy: 0.7955
# Epoch 10/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4541 - accuracy: 0.8022 - val_loss: 0.4377 - val_accuracy: 0.7955
# Epoch 11/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4473 - accuracy: 0.8031 - val_loss: 0.4321 - val_accuracy: 0.7955
# Epoch 12/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4468 - accuracy: 0.8065 - val_loss: 0.4275 - val_accuracy: 0.7959
# Epoch 13/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4469 - accuracy: 0.8050 - val_loss: 0.4283 - val_accuracy: 0.7955
# Epoch 14/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4425 - accuracy: 0.8108 - val_loss: 0.4226 - val_accuracy: 0.7955
# Epoch 15/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4359 - accuracy: 0.8145 - val_loss: 0.4199 - val_accuracy: 0.8012
# Epoch 16/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4299 - accuracy: 0.8149 - val_loss: 0.4138 - val_accuracy: 0.8031
# Epoch 17/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4303 - accuracy: 0.8155 - val_loss: 0.4152 - val_accuracy: 0.8069
# Epoch 18/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4280 - accuracy: 0.8182 - val_loss: 0.4049 - val_accuracy: 0.8092
# Epoch 19/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4242 - accuracy: 0.8224 - val_loss: 0.4026 - val_accuracy: 0.8095
# Epoch 20/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4228 - accuracy: 0.8231 - val_loss: 0.4049 - val_accuracy: 0.8103
# Epoch 21/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4087 - accuracy: 0.8311 - val_loss: 0.3950 - val_accuracy: 0.8164
# Epoch 22/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4080 - accuracy: 0.8293 - val_loss: 0.3868 - val_accuracy: 0.8311
# Epoch 23/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4085 - accuracy: 0.8283 - val_loss: 0.3878 - val_accuracy: 0.8220
# Epoch 24/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4108 - accuracy: 0.8298 - val_loss: 0.3934 - val_accuracy: 0.8164
# Epoch 25/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4057 - accuracy: 0.8300 - val_loss: 0.3882 - val_accuracy: 0.8213
# Epoch 26/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4037 - accuracy: 0.8309 - val_loss: 0.3896 - val_accuracy: 0.8194
# Epoch 27/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.4103 - accuracy: 0.8266 - val_loss: 0.3837 - val_accuracy: 0.8353
# Epoch 28/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4053 - accuracy: 0.8322 - val_loss: 0.3832 - val_accuracy: 0.8289
# Epoch 29/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4026 - accuracy: 0.8278 - val_loss: 0.3835 - val_accuracy: 0.8213
# Epoch 30/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4135 - accuracy: 0.8293 - val_loss: 0.3863 - val_accuracy: 0.8285
# Epoch 31/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4018 - accuracy: 0.8332 - val_loss: 0.3810 - val_accuracy: 0.8334
# Epoch 32/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3970 - accuracy: 0.8322 - val_loss: 0.3797 - val_accuracy: 0.8345
# Epoch 33/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4070 - accuracy: 0.8280 - val_loss: 0.3853 - val_accuracy: 0.8194
# Epoch 34/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3958 - accuracy: 0.8345 - val_loss: 0.3781 - val_accuracy: 0.8289
# Epoch 35/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3962 - accuracy: 0.8322 - val_loss: 0.3748 - val_accuracy: 0.8364
# Epoch 36/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3956 - accuracy: 0.8324 - val_loss: 0.3735 - val_accuracy: 0.8372
# Epoch 37/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3908 - accuracy: 0.8397 - val_loss: 0.3742 - val_accuracy: 0.8319
# Epoch 38/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3990 - accuracy: 0.8321 - val_loss: 0.3765 - val_accuracy: 0.8345
# Epoch 39/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3903 - accuracy: 0.8306 - val_loss: 0.3751 - val_accuracy: 0.8376
# Epoch 40/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3968 - accuracy: 0.8322 - val_loss: 0.3775 - val_accuracy: 0.8342
# Epoch 41/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3904 - accuracy: 0.8343 - val_loss: 0.3733 - val_accuracy: 0.8315
# Epoch 42/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3937 - accuracy: 0.8334 - val_loss: 0.3773 - val_accuracy: 0.8376
# Epoch 43/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3925 - accuracy: 0.8339 - val_loss: 0.3776 - val_accuracy: 0.8232
# Epoch 44/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3954 - accuracy: 0.8285 - val_loss: 0.3781 - val_accuracy: 0.8220
# Epoch 45/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3904 - accuracy: 0.8350 - val_loss: 0.3729 - val_accuracy: 0.8368
# Epoch 46/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3885 - accuracy: 0.8330 - val_loss: 0.3720 - val_accuracy: 0.8368
# Epoch 47/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3925 - accuracy: 0.8334 - val_loss: 0.3721 - val_accuracy: 0.8368
# Epoch 48/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3916 - accuracy: 0.8369 - val_loss: 0.3792 - val_accuracy: 0.8251
# Epoch 49/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3897 - accuracy: 0.8334 - val_loss: 0.3753 - val_accuracy: 0.8251
# Epoch 50/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3879 - accuracy: 0.8371 - val_loss: 0.3769 - val_accuracy: 0.8349
# Epoch 51/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3803 - accuracy: 0.8352 - val_loss: 0.3722 - val_accuracy: 0.8372
# Epoch 52/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3898 - accuracy: 0.8358 - val_loss: 0.3731 - val_accuracy: 0.8349
# Epoch 53/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3880 - accuracy: 0.8367 - val_loss: 0.3796 - val_accuracy: 0.8220
# Epoch 54/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3871 - accuracy: 0.8375 - val_loss: 0.3725 - val_accuracy: 0.8413
# Epoch 55/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3884 - accuracy: 0.8349 - val_loss: 0.3756 - val_accuracy: 0.8273
# Epoch 56/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3835 - accuracy: 0.8334 - val_loss: 0.3742 - val_accuracy: 0.8349
# Epoch 57/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3855 - accuracy: 0.8332 - val_loss: 0.3695 - val_accuracy: 0.8383
# Epoch 58/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3866 - accuracy: 0.8358 - val_loss: 0.3722 - val_accuracy: 0.8307
# Epoch 59/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3827 - accuracy: 0.8347 - val_loss: 0.3709 - val_accuracy: 0.8330
# Epoch 60/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3803 - accuracy: 0.8382 - val_loss: 0.3717 - val_accuracy: 0.8360
# Epoch 61/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3858 - accuracy: 0.8337 - val_loss: 0.3713 - val_accuracy: 0.8368
# Epoch 62/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3899 - accuracy: 0.8321 - val_loss: 0.3690 - val_accuracy: 0.8368
# Epoch 63/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3831 - accuracy: 0.8349 - val_loss: 0.3692 - val_accuracy: 0.8342
# Epoch 64/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3847 - accuracy: 0.8322 - val_loss: 0.3671 - val_accuracy: 0.8395
# Epoch 65/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3832 - accuracy: 0.8367 - val_loss: 0.3680 - val_accuracy: 0.8357
# Epoch 66/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3807 - accuracy: 0.8414 - val_loss: 0.3730 - val_accuracy: 0.8292
# Epoch 67/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3831 - accuracy: 0.8393 - val_loss: 0.3721 - val_accuracy: 0.8353
# Epoch 68/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3791 - accuracy: 0.8378 - val_loss: 0.3690 - val_accuracy: 0.8395
# Epoch 69/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3829 - accuracy: 0.8377 - val_loss: 0.3681 - val_accuracy: 0.8402
# Epoch 70/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3776 - accuracy: 0.8388 - val_loss: 0.3698 - val_accuracy: 0.8421
# Epoch 71/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3844 - accuracy: 0.8365 - val_loss: 0.3679 - val_accuracy: 0.8349
# Epoch 72/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3883 - accuracy: 0.8309 - val_loss: 0.3678 - val_accuracy: 0.8417
# Epoch 73/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3762 - accuracy: 0.8397 - val_loss: 0.3694 - val_accuracy: 0.8383
# Epoch 74/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3808 - accuracy: 0.8373 - val_loss: 0.3685 - val_accuracy: 0.8383
# Epoch 75/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3837 - accuracy: 0.8365 - val_loss: 0.3696 - val_accuracy: 0.8387
# Epoch 76/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3770 - accuracy: 0.8427 - val_loss: 0.3662 - val_accuracy: 0.8413
# Epoch 77/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3825 - accuracy: 0.8352 - val_loss: 0.3641 - val_accuracy: 0.8455
# Epoch 78/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3820 - accuracy: 0.8341 - val_loss: 0.3676 - val_accuracy: 0.8410
# Epoch 79/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3823 - accuracy: 0.8350 - val_loss: 0.3689 - val_accuracy: 0.8406
# Epoch 80/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3782 - accuracy: 0.8367 - val_loss: 0.3685 - val_accuracy: 0.8379
# Epoch 81/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3842 - accuracy: 0.8345 - val_loss: 0.3680 - val_accuracy: 0.8379
# Epoch 82/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3815 - accuracy: 0.8380 - val_loss: 0.3669 - val_accuracy: 0.8383
# Epoch 83/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3791 - accuracy: 0.8356 - val_loss: 0.3653 - val_accuracy: 0.8429
# Epoch 84/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3817 - accuracy: 0.8354 - val_loss: 0.3719 - val_accuracy: 0.8360
# Epoch 85/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3857 - accuracy: 0.8326 - val_loss: 0.3688 - val_accuracy: 0.8330
# Epoch 86/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3790 - accuracy: 0.8362 - val_loss: 0.3701 - val_accuracy: 0.8342
# Epoch 87/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3777 - accuracy: 0.8378 - val_loss: 0.3705 - val_accuracy: 0.8406
# Epoch 88/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3783 - accuracy: 0.8378 - val_loss: 0.3663 - val_accuracy: 0.8455
# Epoch 89/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3775 - accuracy: 0.8406 - val_loss: 0.3691 - val_accuracy: 0.8353
# Epoch 90/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3843 - accuracy: 0.8339 - val_loss: 0.3702 - val_accuracy: 0.8353
# Epoch 91/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3745 - accuracy: 0.8429 - val_loss: 0.3696 - val_accuracy: 0.8432
# Epoch 92/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3802 - accuracy: 0.8332 - val_loss: 0.3659 - val_accuracy: 0.8448
# Epoch 93/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3773 - accuracy: 0.8358 - val_loss: 0.3686 - val_accuracy: 0.8387
# Epoch 94/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3774 - accuracy: 0.8371 - val_loss: 0.3654 - val_accuracy: 0.8436
# Epoch 95/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3756 - accuracy: 0.8419 - val_loss: 0.3634 - val_accuracy: 0.8444
# Epoch 96/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3798 - accuracy: 0.8358 - val_loss: 0.3648 - val_accuracy: 0.8429
# Epoch 97/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3856 - accuracy: 0.8337 - val_loss: 0.3680 - val_accuracy: 0.8413
# Epoch 98/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3833 - accuracy: 0.8328 - val_loss: 0.3682 - val_accuracy: 0.8391
# Epoch 99/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3724 - accuracy: 0.8384 - val_loss: 0.3699 - val_accuracy: 0.8338
# Epoch 100/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3745 - accuracy: 0.8408 - val_loss: 0.3660 - val_accuracy: 0.8406

# %%
print(model_history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# summarize history for accuracy
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')
plt.show()

# %%
# summarize history for loss
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %%
# Predicting the Test set results
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[1573,   22],
#        [ 264,  141]])

# %%
# Calculate the Accuracy
from sklearn.metrics import accuracy_score
score=accuracy_score(y_pred,y_test)
score
# Out:
# 0.857
